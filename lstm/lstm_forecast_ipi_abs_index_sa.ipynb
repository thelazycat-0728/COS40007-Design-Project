# %% [markdown]
# # LSTM Forecast for ipi_abs_index_sa
# This notebook builds an LSTM model to forecast the univariate ipi_abs_index_sa series using a 12-step lookback window with MinMax scaling applied after the train-test split.

# %% [markdown]
# ## Import Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import zscore
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from statsmodels.tsa.stattools import adfuller
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Load the CSV Dataset

# %%
# Load the dataset
df = pd.read_csv('../public/data/combined_air_electricity_ipi_cleaned.csv')

df['date'] = pd.to_datetime(df['date'])
df = df.sort_values('date').reset_index(drop=True)

target_col = 'ipi_abs_index_sa'
print(f'Forecast target: {target_col}')
print(f"Dataset shape before outlier removal: {df.shape}")
print(f"First 5 rows:")
print(df[['date', target_col]].head())
print(f"Last 5 rows:")
print(df[['date', target_col]].tail())

z_scores = np.abs(zscore(df[target_col]))

df[target_col] = np.where(
    z_scores > 3,
    np.nan,
    df[target_col]
)

df[target_col] = df[target_col].interpolate()
print(f"First 5 rows after outlier smoothing:")
print(df[['date', target_col]].head())
print(f"Last 5 rows after outlier smoothing:")
print(df[['date', target_col]].tail())
# Out:
# Forecast target: ipi_abs_index_sa
# Dataset shape before outlier removal: (60, 20)
# First 5 rows:
#         date  ipi_abs_index_sa
# 0 2018-01-01           109.866
# 1 2018-02-01           110.830
# 2 2018-03-01           111.090
# 3 2018-04-01           113.036
# 4 2018-05-01           112.183
# Last 5 rows:
#          date  ipi_abs_index_sa
# 55 2022-08-01           129.242
# 56 2022-09-01           129.370
# 57 2022-10-01           126.123
# 58 2022-11-01           127.845
# 59 2022-12-01           126.652
# First 5 rows after outlier smoothing:
#         date  ipi_abs_index_sa
# 0 2018-01-01           109.866
# 1 2018-02-01           110.830
# 2 2018-03-01           111.090
# 3 2018-04-01           113.036
# 4 2018-05-01           112.183
# Last 5 rows after outlier smoothing:
#          date  ipi_abs_index_sa
# 55 2022-08-01           129.242
# 56 2022-09-01           129.370
# 57 2022-10-01           126.123
# 58 2022-11-01           127.845
# 59 2022-12-01           126.652

# %% [markdown]
# ## Parse Dates and Sort Data

# %%
print(f"Date range: {df['date'].min()} to {df['date'].max()}")
# Out:
# Date range: 2018-01-01 00:00:00 to 2022-12-01 00:00:00

# %% [markdown]
# ## Create Time Series Index and Target

# %%
df.set_index('date', inplace=True)
df[f'log_{target_col}'] = np.log(df[target_col])
log_series = df[f'log_{target_col}']
print(f'Log transformation applied to {target_col}.')

def run_adf_test(series, alpha=0.05):
    result = adfuller(series, autolag='AIC')
    print(f'ADF statistic: {result[0]:.4f}, p-value: {result[1]:.4f}, usedlag: {result[2]}, nobs: {result[3]}')
    return result[1] <= alpha

difference_order = 0
processed_series = log_series.copy()
print('ADF test on log-transformed series:')
if not run_adf_test(processed_series):
    processed_series = processed_series.diff().dropna()
    difference_order = 1
    print('Series was not stationary. Applied first-order differencing.')
    print('ADF test after first differencing:')
    if not run_adf_test(processed_series):
        processed_series = processed_series.diff().dropna()
        difference_order = 2
        print('Series still not stationary. Applied second-order differencing.')
        print('ADF test after second differencing:')
        if not run_adf_test(processed_series):
            print('Warning: series is still non-stationary after second differencing.')

if difference_order == 0:
    print('Final series uses log-transformed values with no differencing.')
else:
    print(f'Final series uses log-transformed values with differencing order = {difference_order}.')

print(f'Final processed data length: {len(processed_series)}')
data = processed_series.values.reshape(-1, 1)
print(f'Data shape: {data.shape}')
# Out:
# Log transformation applied to ipi_abs_index_sa.
# ADF test on log-transformed series:
# ADF statistic: -2.4970, p-value: 0.1162, usedlag: 0, nobs: 59
# Series was not stationary. Applied first-order differencing.
# ADF test after first differencing:
# ADF statistic: -6.8896, p-value: 0.0000, usedlag: 2, nobs: 56
# Final series uses log-transformed values with differencing order = 1.
# Final processed data length: 59
# Data shape: (59, 1)

# %% [markdown]
# ## Split Data into Train and Test (Last 12 Months)

# %%
test_size = 12
train_data = data[:-test_size]
test_data = data[-test_size:]

print(f'Train data shape: {train_data.shape}')
print(f'Test data shape: {test_data.shape}')
print(f'Train range: {len(train_data)} months')
print(f'Test range: {len(test_data)} months')
# Out:
# Train data shape: (47, 1)
# Test data shape: (12, 1)
# Train range: 47 months
# Test range: 12 months

# %% [markdown]
# ## Scale Data with MinMaxScaler After Split

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
train_scaled = scaler.fit_transform(train_data)
test_scaled = scaler.transform(test_data)

print(f'Scaled train shape: {train_scaled.shape}')
print(f'Scaled test shape: {test_scaled.shape}')
print(f'Scaler min: {scaler.data_min_[0]:.2f}, max: {scaler.data_max_[0]:.2f}')
# Out:
# Scaled train shape: (47, 1)
# Scaled test shape: (12, 1)
# Scaler min: -0.09, max: 0.21

# %% [markdown]
# ## Create LSTM Input Sequences

# %%
def create_sequences(data, lookback=3):
    X, y = [], []
    for i in range(lookback, len(data)):
        X.append(data[i - lookback:i, 0:1])
        y.append(data[i, 0])
    return np.array(X), np.array(y)

lookback = 3

X_train, y_train = create_sequences(train_scaled, lookback)

test_extended = np.vstack((train_scaled[-lookback:], test_scaled))
X_test, y_test = create_sequences(test_extended, lookback)

print(f'X_train shape: {X_train.shape}')
print(f'X_test shape: {X_test.shape}')
print(f'Selected lookback from ACF: {lookback}')
# Out:
# X_train shape: (44, 3, 1)
# X_test shape: (12, 3, 1)
# Selected lookback from ACF: 3

# %% [markdown]
# ## Train the Model

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2

print('Training the LSTM model with walk-forward validation...')

def create_model(lookback=3):
    model = Sequential([
        LSTM(8, input_shape=(lookback, 1),
             kernel_regularizer=l2(1e-4),
             recurrent_regularizer=l2(1e-4)),
        Dense(4, activation='relu', kernel_regularizer=l2(1e-4)),
        Dense(1)
    ])
    model.compile(optimizer='adam', loss='mse')
    return model

def walk_forward_validation(scaled_data, lookback=3, val_size=4, n_splits=3):
    total_len = len(scaled_data)
    max_splits = (total_len - lookback - val_size) // val_size
    if max_splits < 1:
        raise ValueError('Not enough data for walk-forward validation with the given parameters.')

    n_splits = min(n_splits, max_splits)
    metrics = []

    for split in range(n_splits):
        initial_train_size = 20           # reduced: 30 was too large for 48 pts
        train_end = initial_train_size + (split + 1) * val_size
        val_start = train_end
        val_end = val_start + val_size

        if val_end > total_len:
            print(f'Fold {split + 1}: not enough data, skipping.')
            break

        train_window = scaled_data[:train_end]
        val_window = scaled_data[val_start:val_end]

        X_train_w, y_train_w = create_sequences(train_window, lookback)
        X_val_w, y_val_w = create_sequences(
            np.vstack((train_window[-lookback:], val_window)),
            lookback
        )

        fold_model = create_model(lookback)
        fold_model.fit(
            X_train_w,
            y_train_w,
            epochs=200,                   # more epochs, early stopping will brake
            batch_size=2,                 # tiny batch for small data
            validation_data=(X_val_w, y_val_w),
            callbacks=[
                EarlyStopping(
                    monitor='val_loss',
                    patience=20,          # more patience to avoid premature stop
                    restore_best_weights=True,
                    verbose=0
                ),
                ReduceLROnPlateau(        # decay LR when val_loss plateaus
                    monitor='val_loss',
                    factor=0.5,
                    patience=10,
                    min_lr=1e-5,
                    verbose=0
                )
            ],
            shuffle=False,
            verbose=0
        )

        y_val_pred = fold_model.predict(X_val_w, verbose=0)
        mae = mean_absolute_error(y_val_w, y_val_pred)
        rmse = np.sqrt(mean_squared_error(y_val_w, y_val_pred))
        r2 = r2_score(y_val_w, y_val_pred)
        metrics.append((mae, rmse, r2))

        print(
            f'Fold {split + 1}: train_end={train_end}, val_end={val_end}, '
            f'MAE={mae:.6f}, RMSE={rmse:.6f}, R²={r2:.6f}'
        )

    return metrics

# val_size=4, n_splits=3 — keeps each fold's val set small and folds feasible
metrics = walk_forward_validation(train_scaled, lookback=lookback, val_size=4, n_splits=3)

mae_values = [m[0] for m in metrics]
rmse_values = [m[1] for m in metrics]
r2_values = [m[2] for m in metrics]

print('Walk-forward validation summary:')
print(f'Average MAE:  {np.mean(mae_values):.6f}')
print(f'Average RMSE: {np.mean(rmse_values):.6f}')
print(f'Average R²:   {np.mean(r2_values):.6f}')

print('Training final model on the full training set...')
model = create_model(lookback)
history = model.fit(
    X_train,
    y_train,
    epochs=200,
    batch_size=2,                         # small batch for final train too
    validation_split=0.15,
    callbacks=[
        EarlyStopping(
            monitor='val_loss',
            patience=20,
            restore_best_weights=True,
            verbose=1
        ),
        ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.5,
            patience=10,
            min_lr=1e-5,
            verbose=1
        )
    ],
    shuffle=False,
    verbose=1
)

print('Training completed!')
# Out:
# Training the LSTM model with walk-forward validation...
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Fold 1: train_end=24, val_end=28, MAE=0.129620, RMSE=0.163641, R²=0.044901
# Fold 2: train_end=28, val_end=32, MAE=0.274114, RMSE=0.421562, R²=-0.745690
# Fold 3: train_end=32, val_end=36, MAE=0.053972, RMSE=0.063674, R²=-0.034514
# Walk-forward validation summary:
# Average MAE:  0.152568
# Average RMSE: 0.216292
# Average R²:   -0.245101
# Training final model on the full training set...
# Epoch 1/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - loss: 0.1126 - val_loss: 0.0895 - learning_rate: 0.0010
# Epoch 2/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0959 - val_loss: 0.0773 - learning_rate: 0.0010
# Epoch 3/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0842 - val_loss: 0.0649 - learning_rate: 0.0010
# Epoch 4/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0722 - val_loss: 0.0522 - learning_rate: 0.0010
# Epoch 5/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0601 - val_loss: 0.0394 - learning_rate: 0.0010
# Epoch 6/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0485 - val_loss: 0.0274 - learning_rate: 0.0010
# Epoch 7/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0381 - val_loss: 0.0170 - learning_rate: 0.0010
# Epoch 8/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0301 - val_loss: 0.0097 - learning_rate: 0.0010
# Epoch 9/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0258 - val_loss: 0.0063 - learning_rate: 0.0010
# Epoch 10/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0245 - val_loss: 0.0054 - learning_rate: 0.0010
# Epoch 11/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0242 - val_loss: 0.0053 - learning_rate: 0.0010
# Epoch 12/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0241 - val_loss: 0.0053 - learning_rate: 0.0010
# Epoch 13/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0240 - val_loss: 0.0052 - learning_rate: 0.0010
# Epoch 14/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0239 - val_loss: 0.0052 - learning_rate: 0.0010
# Epoch 15/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0239 - val_loss: 0.0052 - learning_rate: 0.0010
# Epoch 16/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0238 - val_loss: 0.0051 - learning_rate: 0.0010
# Epoch 17/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0237 - val_loss: 0.0051 - learning_rate: 0.0010
# Epoch 18/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0236 - val_loss: 0.0051 - learning_rate: 0.0010
# Epoch 19/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0236 - val_loss: 0.0050 - learning_rate: 0.0010
# Epoch 20/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0235 - val_loss: 0.0050 - learning_rate: 0.0010
# Epoch 21/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0234 - val_loss: 0.0050 - learning_rate: 0.0010
# Epoch 22/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0234 - val_loss: 0.0050 - learning_rate: 0.0010
# Epoch 23/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0233 - val_loss: 0.0050 - learning_rate: 0.0010
# Epoch 24/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0232 - val_loss: 0.0049 - learning_rate: 0.0010
# Epoch 25/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0232 - val_loss: 0.0049 - learning_rate: 0.0010
# Epoch 26/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0231 - val_loss: 0.0049 - learning_rate: 0.0010
# Epoch 27/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0231 - val_loss: 0.0049 - learning_rate: 0.0010
# Epoch 28/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0230 - val_loss: 0.0049 - learning_rate: 0.0010
# Epoch 29/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0230 - val_loss: 0.0049 - learning_rate: 0.0010
# Epoch 30/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0229 - val_loss: 0.0049 - learning_rate: 0.0010
# Epoch 31/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0229 - val_loss: 0.0049 - learning_rate: 0.0010
# Epoch 32/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0228 - val_loss: 0.0048 - learning_rate: 0.0010
# Epoch 33/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0228 - val_loss: 0.0048 - learning_rate: 0.0010
# Epoch 34/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0227 - val_loss: 0.0048 - learning_rate: 0.0010
# Epoch 35/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0227 - val_loss: 0.0048 - learning_rate: 0.0010
# Epoch 36/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0226 - val_loss: 0.0048 - learning_rate: 0.0010
# Epoch 37/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0225 - val_loss: 0.0048 - learning_rate: 0.0010
# Epoch 38/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0225 - val_loss: 0.0048 - learning_rate: 0.0010
# Epoch 39/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0224 - val_loss: 0.0048 - learning_rate: 0.0010
# Epoch 40/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0224 - val_loss: 0.0048 - learning_rate: 0.0010
# Epoch 41/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0223 - val_loss: 0.0048 - learning_rate: 0.0010
# Epoch 42/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0223 - val_loss: 0.0048 - learning_rate: 0.0010
# Epoch 43/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0222 - val_loss: 0.0048 - learning_rate: 0.0010
# Epoch 44/200
# 15/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0073
# Epoch 44: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0222 - val_loss: 0.0048 - learning_rate: 0.0010
# Epoch 45/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0221 - val_loss: 0.0048 - learning_rate: 5.0000e-04
# Epoch 46/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0221 - val_loss: 0.0048 - learning_rate: 5.0000e-04
# Epoch 47/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0221 - val_loss: 0.0048 - learning_rate: 5.0000e-04
# Epoch 48/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0220 - val_loss: 0.0048 - learning_rate: 5.0000e-04
# Epoch 49/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0220 - val_loss: 0.0048 - learning_rate: 5.0000e-04
# Epoch 50/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0220 - val_loss: 0.0048 - learning_rate: 5.0000e-04
# Epoch 51/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0219 - val_loss: 0.0048 - learning_rate: 5.0000e-04
# Epoch 52/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0219 - val_loss: 0.0048 - learning_rate: 5.0000e-04
# Epoch 53/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0219 - val_loss: 0.0048 - learning_rate: 5.0000e-04
# Epoch 54/200
# 13/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0042
# Epoch 54: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0218 - val_loss: 0.0048 - learning_rate: 5.0000e-04
# Epoch 55/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0218 - val_loss: 0.0048 - learning_rate: 2.5000e-04
# Epoch 56/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0218 - val_loss: 0.0048 - learning_rate: 2.5000e-04
# Epoch 57/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0218 - val_loss: 0.0048 - learning_rate: 2.5000e-04
# Epoch 58/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0218 - val_loss: 0.0048 - learning_rate: 2.5000e-04
# Epoch 59/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0218 - val_loss: 0.0048 - learning_rate: 2.5000e-04
# Epoch 60/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0217 - val_loss: 0.0048 - learning_rate: 2.5000e-04
# Epoch 61/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0217 - val_loss: 0.0048 - learning_rate: 2.5000e-04
# Epoch 62/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0217 - val_loss: 0.0048 - learning_rate: 2.5000e-04
# Epoch 63/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0217 - val_loss: 0.0048 - learning_rate: 2.5000e-04
# Epoch 64/200
# 16/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0082
# Epoch 64: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0217 - val_loss: 0.0048 - learning_rate: 2.5000e-04
# Epoch 65/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0217 - val_loss: 0.0048 - learning_rate: 1.2500e-04
# Epoch 66/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0217 - val_loss: 0.0048 - learning_rate: 1.2500e-04
# Epoch 67/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0216 - val_loss: 0.0048 - learning_rate: 1.2500e-04
# Epoch 68/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0216 - val_loss: 0.0048 - learning_rate: 1.2500e-04
# Epoch 69/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0216 - val_loss: 0.0048 - learning_rate: 1.2500e-04
# Epoch 70/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0216 - val_loss: 0.0048 - learning_rate: 1.2500e-04
# Epoch 71/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0216 - val_loss: 0.0048 - learning_rate: 1.2500e-04
# Epoch 72/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0216 - val_loss: 0.0048 - learning_rate: 1.2500e-04
# Epoch 73/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0216 - val_loss: 0.0048 - learning_rate: 1.2500e-04
# Epoch 74/200
# 14/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0058
# Epoch 74: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0216 - val_loss: 0.0048 - learning_rate: 1.2500e-04
# Epoch 75/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0216 - val_loss: 0.0048 - learning_rate: 6.2500e-05
# Epoch 76/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0216 - val_loss: 0.0048 - learning_rate: 6.2500e-05
# Epoch 77/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0216 - val_loss: 0.0048 - learning_rate: 6.2500e-05
# Epoch 78/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0216 - val_loss: 0.0048 - learning_rate: 6.2500e-05
# Epoch 79/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0216 - val_loss: 0.0048 - learning_rate: 6.2500e-05
# Epoch 80/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0216 - val_loss: 0.0048 - learning_rate: 6.2500e-05
# Epoch 81/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0216 - val_loss: 0.0048 - learning_rate: 6.2500e-05
# Epoch 82/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0216 - val_loss: 0.0048 - learning_rate: 6.2500e-05
# Epoch 83/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 6.2500e-05
# Epoch 84/200
#  1/19 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0011
# Epoch 84: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 6.2500e-05
# Epoch 85/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 3.1250e-05
# Epoch 86/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 3.1250e-05
# Epoch 87/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 3.1250e-05
# Epoch 88/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 3.1250e-05
# Epoch 89/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 3.1250e-05
# Epoch 90/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 3.1250e-05
# Epoch 91/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 3.1250e-05
# Epoch 92/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 3.1250e-05
# Epoch 93/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 3.1250e-05
# Epoch 94/200
#  1/19 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0011
# Epoch 94: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 3.1250e-05
# Epoch 95/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.5625e-05
# Epoch 96/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.5625e-05
# Epoch 97/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.5625e-05
# Epoch 98/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.5625e-05
# Epoch 99/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.5625e-05
# Epoch 100/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.5625e-05
# Epoch 101/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.5625e-05
# Epoch 102/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.5625e-05
# Epoch 103/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.5625e-05
# Epoch 104/200
#  1/19 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0011
# Epoch 104: ReduceLROnPlateau reducing learning rate to 1e-05.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.5625e-05
# Epoch 105/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 106/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 107/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 108/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 109/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 110/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 111/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 112/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 113/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 114/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 115/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 116/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 117/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 118/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 119/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 120/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 121/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 122/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 123/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 124/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 125/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 126/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 127/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 128/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 129/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 130/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 131/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 132/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 133/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 134/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 135/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 136/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 137/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 138/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 139/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 140/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 141/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 142/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 143/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 144/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 145/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 146/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 147/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 148/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 149/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 150/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 151/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 152/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 153/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 154/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 155/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 156/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 157/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 158/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 159/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 160/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 161/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 162/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 163/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 164/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 165/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 166/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 167/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 168/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 169/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 170/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 171/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 172/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 173/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 174/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 175/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 176/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 177/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 178/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 179/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 180/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 181/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 182/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 183/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 184/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 185/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 186/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 187/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 188/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 189/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 190/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 191/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 192/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 193/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 194/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 195/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 196/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 197/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 198/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 199/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0215 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Epoch 200/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0214 - val_loss: 0.0048 - learning_rate: 1.0000e-05
# Restoring model weights from the end of the best epoch: 200.
# Training completed!

# %% [markdown]
# ## Evaluate with MAE, RMSE, and R2

# %%
y_pred_scaled = model.predict(X_test, verbose=0)

mae_scaled = mean_absolute_error(y_test, y_pred_scaled)
rmse_scaled = np.sqrt(mean_absolute_error(y_test, y_pred_scaled))
r2_scaled = r2_score(y_test, y_pred_scaled)

print('=== Metrics on Scaled Data ===')
print(f'MAE (scaled): {mae_scaled:.6f}')
print(f'RMSE (scaled): {rmse_scaled:.6f}')
print(f'R² (scaled):   {r2_scaled:.6f}')

# 1. Save the model architecture to a JSON file
model_json = model.to_json()
with open("lstm_model_ipi_abs_index_sa_forecast.json", "w") as json_file:
    json_file.write(model_json)

# 2. Save the weights to a separate HDF5 file
model.save_weights("lstm_model_ipi_abs_index_sa_forecast.weights.h5")
# Out:
# === Metrics on Scaled Data ===
# MAE (scaled): 0.053882
# RMSE (scaled): 0.232125
# R² (scaled):   -0.018245

# %% [markdown]
# ## Inverse Scale Predictions

# %%
# ─── Inverse-scale ────────────────────────────────────────────────────────────
# y_test and y_pred are shape (samples,) — reshape to (samples, 1) for scaler
y_pred_diff = scaler.inverse_transform(y_pred_scaled.reshape(-1, 1))  # (samples, 1)
y_test_diff = scaler.inverse_transform(y_test.reshape(-1, 1))         # (samples, 1)

# ─── Undo differencing ────────────────────────────────────────────────────────
# Each predicted value at position i corresponds to log_series index:
# -(test_size) + i, so the anchor is always log_series aligned to the TEST window

if difference_order == 0:
    y_pred_log_values = y_pred_diff
    y_test_log_values = y_test_diff  # already in log domain after inverse-scale

elif difference_order == 1:
    # anchor: the actual log value ONE step before each test prediction
    # log_series[-test_size - 1 : -1] gives exactly test_size anchor points
    prev1 = log_series.iloc[-test_size - 1:-1].values.reshape(-1, 1)
    y_pred_log_values = y_pred_diff + prev1
    y_test_log_values = log_series.iloc[-test_size:].values.reshape(-1, 1)

else:  # difference_order == 2
    prev1 = log_series.iloc[-test_size - 1:-1].values.reshape(-1, 1)
    prev2 = log_series.iloc[-test_size - 2:-2].values.reshape(-1, 1)
    y_pred_log_values = y_pred_diff + 2 * prev1 - prev2
    y_test_log_values = log_series.iloc[-test_size:].values.reshape(-1, 1)

# ─── Undo log transform ───────────────────────────────────────────────────────
y_pred_original = np.exp(y_pred_log_values)
y_test_original = np.exp(y_test_log_values)

# ─── Sanity checks ────────────────────────────────────────────────────────────
assert y_pred_original.shape == y_test_original.shape, \
    f"Shape mismatch! Preds: {y_pred_original.shape}, Actuals: {y_test_original.shape}"
assert len(y_pred_original) == test_size, \
    f"Expected {test_size} predictions, got {len(y_pred_original)}"

# ─── Metrics on original scale ────────────────────────────────────────────────
mae_original  = mean_absolute_error(y_test_original, y_pred_original)
rmse_original = np.sqrt(mean_absolute_error(y_test_original, y_pred_original))
r2_original   = r2_score(y_test_original, y_pred_original)

print("=== Metrics on Original Scale ===")
print(f"MAE (original): {mae_original:.20f}")
print(f"RMSE (original): {rmse_original:.20f}")
print(f"R²   (original): {r2_original:.6f}")
# Out:
# === Metrics on Original Scale ===
# MAE (original): 2.06404493802973965089
# RMSE (original): 1.43667843932793104500
# R²   (original): -0.151147

# %%
# Create prediction vs actual plot
plt.figure(figsize=(14, 6))

# Plot flattened actual values and predictions
plt.plot(y_test_original.flatten(), marker='o', linestyle='-', 
         linewidth=1.5, label='Actual', color='#2E86AB', markersize=4)
plt.plot(y_pred_original.flatten(), marker='s', linestyle='--', 
         linewidth=1.5, label='LSTM Prediction', color='#A23B72', markersize=4)

plt.title('LSTM Forecast vs Actual', fontsize=14, fontweight='bold')
plt.xlabel('Flattened Test Points', fontsize=12)
plt.ylabel('IPI ABS Index SA', fontsize=12)
plt.legend(fontsize=11, loc='best')
plt.grid(True, alpha=0.3)

# Add metrics to the plot
metrics_text = f'MAE: {mae_original:.20f}\nRMSE: {rmse_original:.20f}\nR²: {r2_original:.4f}'
plt.text(0.02, 0.98, metrics_text, transform=plt.gca().transAxes, 
         fontsize=11, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))

plt.tight_layout()
plt.show()

print(f"\n✓ Forecast completed successfully!")
# Out:
# ✓ Forecast completed successfully!
