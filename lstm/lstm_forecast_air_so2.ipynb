# %% [markdown]
# # LSTM Forecast for air_so2
# This notebook builds an LSTM model to forecast the univariate air_so2 series using a 12-step lookback window with MinMax scaling applied after the train-test split.

# %% [markdown]
# ## Import Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import zscore
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score
from statsmodels.tsa.stattools import adfuller
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Load the CSV Dataset

# %%
# Load the dataset
df = pd.read_csv('../public/data/combined_air_electricity_ipi_cleaned.csv')

df['date'] = pd.to_datetime(df['date'])
df = df.sort_values('date').reset_index(drop=True)

target_col = 'air_so2'
print(f'Forecast target: {target_col}')
print(f"Dataset shape before outlier removal: {df.shape}")
print(f"First 5 rows:")
print(df[['date', target_col]].head())
print(f"Last 5 rows:")
print(df[['date', target_col]].tail())

z_scores = np.abs(zscore(df[target_col]))

df[target_col] = np.where(
    z_scores > 3,
    np.nan,
    df[target_col]
)

df[target_col] = df[target_col].interpolate()
print(f"First 5 rows after outlier smoothing:")
print(df[['date', target_col]].head())
print(f"Last 5 rows after outlier smoothing:")
print(df[['date', target_col]].tail())
# Out:
# Forecast target: air_so2
# Dataset shape before outlier removal: (60, 19)
# First 5 rows:
#         date  air_so2
# 0 2018-01-01   0.0010
# 1 2018-02-01   0.0011
# 2 2018-03-01   0.0010
# 3 2018-04-01   0.0010
# 4 2018-05-01   0.0010
# Last 5 rows:
#          date  air_so2
# 55 2022-08-01   0.0012
# 56 2022-09-01   0.0012
# 57 2022-10-01   0.0012
# 58 2022-11-01   0.0012
# 59 2022-12-01   0.0013
# First 5 rows after outlier smoothing:
#         date  air_so2
# 0 2018-01-01   0.0010
# 1 2018-02-01   0.0011
# 2 2018-03-01   0.0010
# 3 2018-04-01   0.0010
# 4 2018-05-01   0.0010
# Last 5 rows after outlier smoothing:
#          date  air_so2
# 55 2022-08-01   0.0012
# 56 2022-09-01   0.0012
# 57 2022-10-01   0.0012
# 58 2022-11-01   0.0012
# 59 2022-12-01   0.0013

# %% [markdown]
# ## Parse Dates and Sort Data

# %%
print(f"Date range: {df['date'].min()} to {df['date'].max()}")
print(f"Total months after outlier removal: {len(df)}")
# Out:
# Date range: 2018-01-01 00:00:00 to 2022-12-01 00:00:00
# Total months after outlier removal: 60

# %% [markdown]
# ## Create Time Series Index and Target

# %%
df.set_index('date', inplace=True)
df[f'log_{target_col}'] = np.log(df[target_col])
log_series = df[f'log_{target_col}']
print(f'Log transformation applied to {target_col}.')

def run_adf_test(series, alpha=0.05):
    result = adfuller(series, autolag='AIC')
    print(f'ADF statistic: {result[0]:.4f}, p-value: {result[1]:.4f}, usedlag: {result[2]}, nobs: {result[3]}')
    return result[1] <= alpha

difference_order = 0
processed_series = log_series.copy()
print('ADF test on log-transformed series:')
if not run_adf_test(processed_series):
    processed_series = processed_series.diff().dropna()
    difference_order = 1
    print('Series was not stationary. Applied first-order differencing.')
    print('ADF test after first differencing:')
    if not run_adf_test(processed_series):
        processed_series = processed_series.diff().dropna()
        difference_order = 2
        print('Series still not stationary. Applied second-order differencing.')
        print('ADF test after second differencing:')
        if not run_adf_test(processed_series):
            print('Warning: series is still non-stationary after second differencing.')

if difference_order == 0:
    print('Final series uses log-transformed values with no differencing.')
else:
    print(f'Final series uses log-transformed values with differencing order = {difference_order}.')

print(f'Final processed data length: {len(processed_series)}')
data = processed_series.values.reshape(-1, 1)
print(f'Data shape: {data.shape}')
# Out:
# Log transformation applied to air_so2.
# ADF test on log-transformed series:
# ADF statistic: 0.4149, p-value: 0.9820, usedlag: 11, nobs: 48
# Series was not stationary. Applied first-order differencing.
# ADF test after first differencing:
# ADF statistic: -5.7568, p-value: 0.0000, usedlag: 10, nobs: 48
# Final series uses log-transformed values with differencing order = 1.
# Final processed data length: 59
# Data shape: (59, 1)

# %% [markdown]
# ## Split Data into Train and Test (Last 12 Months)

# %%
test_size = 12
train_data = data[:-test_size]
test_data = data[-test_size:]

print(f'Train data shape: {train_data.shape}')
print(f'Test data shape: {test_data.shape}')
print(f'Train range: {len(train_data)} months')
print(f'Test range: {len(test_data)} months')
# Out:
# Train data shape: (47, 1)
# Test data shape: (12, 1)
# Train range: 47 months
# Test range: 12 months

# %% [markdown]
# ## Scale Data with MinMaxScaler After Split

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
train_scaled = scaler.fit_transform(train_data)
test_scaled = scaler.transform(test_data)

print(f'Scaled train shape: {train_scaled.shape}')
print(f'Scaled test shape: {test_scaled.shape}')
print(f'Scaler min: {scaler.data_min_[0]:.2f}, max: {scaler.data_max_[0]:.2f}')
# Out:
# Scaled train shape: (47, 1)
# Scaled test shape: (12, 1)
# Scaler min: -0.17, max: 0.17

# %% [markdown]
# ## Create LSTM Input Sequences

# %%
def create_sequences(data, lookback=3):
    X, y = [], []
    for i in range(lookback, len(data)):
        X.append(data[i - lookback:i, 0:1])
        y.append(data[i, 0])
    return np.array(X), np.array(y)

lookback = 3

X_train, y_train = create_sequences(train_scaled, lookback)

test_extended = np.vstack((train_scaled[-lookback:], test_scaled))
X_test, y_test = create_sequences(test_extended, lookback)

print(f'X_train shape: {X_train.shape}')
print(f'X_test shape: {X_test.shape}')
print(f'Selected lookback from ACF: {lookback}')
# Out:
# X_train shape: (44, 3, 1)
# X_test shape: (12, 3, 1)
# Selected lookback from ACF: 3

# %% [markdown]
# ## Train the Model

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2

print('Training the LSTM model with walk-forward validation...')

def create_model(lookback=3):
    model = Sequential([
        LSTM(8, input_shape=(lookback, 1),
             kernel_regularizer=l2(1e-4),
             recurrent_regularizer=l2(1e-4)),
        Dense(4, activation='relu', kernel_regularizer=l2(1e-4)),
        Dense(1)
    ])
    model.compile(optimizer='adam', loss='mse')
    return model

def walk_forward_validation(scaled_data, lookback=3, val_size=4, n_splits=3):
    total_len = len(scaled_data)
    max_splits = (total_len - lookback - val_size) // val_size
    if max_splits < 1:
        raise ValueError('Not enough data for walk-forward validation with the given parameters.')

    n_splits = min(n_splits, max_splits)
    metrics = []

    for split in range(n_splits):
        initial_train_size = 20           # reduced: 30 was too large for 48 pts
        train_end = initial_train_size + (split + 1) * val_size
        val_start = train_end
        val_end = val_start + val_size

        if val_end > total_len:
            print(f'Fold {split + 1}: not enough data, skipping.')
            break

        train_window = scaled_data[:train_end]
        val_window = scaled_data[val_start:val_end]

        X_train_w, y_train_w = create_sequences(train_window, lookback)
        X_val_w, y_val_w = create_sequences(
            np.vstack((train_window[-lookback:], val_window)),
            lookback
        )

        fold_model = create_model(lookback)
        fold_model.fit(
            X_train_w,
            y_train_w,
            epochs=200,                   # more epochs, early stopping will brake
            batch_size=2,                 # tiny batch for small data
            validation_data=(X_val_w, y_val_w),
            callbacks=[
                EarlyStopping(
                    monitor='val_loss',
                    patience=20,          # more patience to avoid premature stop
                    restore_best_weights=True,
                    verbose=0
                ),
                ReduceLROnPlateau(        # decay LR when val_loss plateaus
                    monitor='val_loss',
                    factor=0.5,
                    patience=10,
                    min_lr=1e-5,
                    verbose=0
                )
            ],
            shuffle=False,
            verbose=0
        )

        y_val_pred = fold_model.predict(X_val_w, verbose=0)
        mse = mean_squared_error(y_val_w, y_val_pred)
        rmse = np.sqrt(mse)
        r2 = r2_score(y_val_w, y_val_pred)
        metrics.append((mse, rmse, r2))

        print(
            f'Fold {split + 1}: train_end={train_end}, val_end={val_end}, '
            f'MSE={mse:.6f}, RMSE={rmse:.6f}, R²={r2:.6f}'
        )

    return metrics

# val_size=4, n_splits=3 — keeps each fold's val set small and folds feasible
metrics = walk_forward_validation(train_scaled, lookback=lookback, val_size=4, n_splits=3)

mse_values = [m[0] for m in metrics]
rmse_values = [m[1] for m in metrics]
r2_values = [m[2] for m in metrics]

print('Walk-forward validation summary:')
print(f'Average MSE:  {np.mean(mse_values):.6f}')
print(f'Average RMSE: {np.mean(rmse_values):.6f}')
print(f'Average R²:   {np.mean(r2_values):.6f}')

print('Training final model on the full training set...')
model = create_model(lookback)
history = model.fit(
    X_train,
    y_train,
    epochs=200,
    batch_size=2,                         # small batch for final train too
    validation_split=0.15,
    callbacks=[
        EarlyStopping(
            monitor='val_loss',
            patience=20,
            restore_best_weights=True,
            verbose=1
        ),
        ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.5,
            patience=10,
            min_lr=1e-5,
            verbose=1
        )
    ],
    shuffle=False,
    verbose=1
)

print('Training completed!')
# Out:
# Training the LSTM model with walk-forward validation...
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Fold 1: train_end=24, val_end=28, MSE=0.023190, RMSE=0.152282, R²=-0.243694
# Fold 2: train_end=28, val_end=32, MSE=0.049386, RMSE=0.222229, R²=-1.179479
# Fold 3: train_end=32, val_end=36, MSE=0.033387, RMSE=0.182720, R²=0.015478
# Walk-forward validation summary:
# Average MSE:  0.035321
# Average RMSE: 0.185744
# Average R²:   -0.469231
# Training final model on the full training set...
# Epoch 1/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.2996 - val_loss: 0.3310 - learning_rate: 0.0010
# Epoch 2/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2758 - val_loss: 0.3114 - learning_rate: 0.0010
# Epoch 3/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2587 - val_loss: 0.2809 - learning_rate: 0.0010
# Epoch 4/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2168 - val_loss: 0.2177 - learning_rate: 0.0010
# Epoch 5/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1661 - val_loss: 0.1596 - learning_rate: 0.0010
# Epoch 6/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1229 - val_loss: 0.1096 - learning_rate: 0.0010
# Epoch 7/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0897 - val_loss: 0.0713 - learning_rate: 0.0010
# Epoch 8/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0689 - val_loss: 0.0474 - learning_rate: 0.0010
# Epoch 9/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0593 - val_loss: 0.0356 - learning_rate: 0.0010
# Epoch 10/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0560 - val_loss: 0.0308 - learning_rate: 0.0010
# Epoch 11/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0551 - val_loss: 0.0291 - learning_rate: 0.0010
# Epoch 12/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0547 - val_loss: 0.0284 - learning_rate: 0.0010
# Epoch 13/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0546 - val_loss: 0.0281 - learning_rate: 0.0010
# Epoch 14/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0544 - val_loss: 0.0280 - learning_rate: 0.0010
# Epoch 15/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0543 - val_loss: 0.0278 - learning_rate: 0.0010
# Epoch 16/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0541 - val_loss: 0.0277 - learning_rate: 0.0010
# Epoch 17/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0540 - val_loss: 0.0276 - learning_rate: 0.0010
# Epoch 18/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0539 - val_loss: 0.0275 - learning_rate: 0.0010
# Epoch 19/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0538 - val_loss: 0.0273 - learning_rate: 0.0010
# Epoch 20/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0537 - val_loss: 0.0272 - learning_rate: 0.0010
# Epoch 21/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0536 - val_loss: 0.0271 - learning_rate: 0.0010
# Epoch 22/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0535 - val_loss: 0.0270 - learning_rate: 0.0010
# Epoch 23/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0534 - val_loss: 0.0269 - learning_rate: 0.0010
# Epoch 24/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0533 - val_loss: 0.0268 - learning_rate: 0.0010
# Epoch 25/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0532 - val_loss: 0.0267 - learning_rate: 0.0010
# Epoch 26/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0531 - val_loss: 0.0266 - learning_rate: 0.0010
# Epoch 27/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0530 - val_loss: 0.0265 - learning_rate: 0.0010
# Epoch 28/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0529 - val_loss: 0.0264 - learning_rate: 0.0010
# Epoch 29/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0528 - val_loss: 0.0263 - learning_rate: 0.0010
# Epoch 30/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0527 - val_loss: 0.0262 - learning_rate: 0.0010
# Epoch 31/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0526 - val_loss: 0.0261 - learning_rate: 0.0010
# Epoch 32/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0525 - val_loss: 0.0260 - learning_rate: 0.0010
# Epoch 33/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0524 - val_loss: 0.0259 - learning_rate: 0.0010
# Epoch 34/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0522 - val_loss: 0.0258 - learning_rate: 0.0010
# Epoch 35/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0521 - val_loss: 0.0256 - learning_rate: 0.0010
# Epoch 36/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0520 - val_loss: 0.0255 - learning_rate: 0.0010
# Epoch 37/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0519 - val_loss: 0.0254 - learning_rate: 0.0010
# Epoch 38/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0518 - val_loss: 0.0253 - learning_rate: 0.0010
# Epoch 39/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0517 - val_loss: 0.0252 - learning_rate: 0.0010
# Epoch 40/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0516 - val_loss: 0.0251 - learning_rate: 0.0010
# Epoch 41/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0514 - val_loss: 0.0250 - learning_rate: 0.0010
# Epoch 42/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0513 - val_loss: 0.0248 - learning_rate: 0.0010
# Epoch 43/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0512 - val_loss: 0.0247 - learning_rate: 0.0010
# Epoch 44/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0510 - val_loss: 0.0246 - learning_rate: 0.0010
# Epoch 45/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0509 - val_loss: 0.0244 - learning_rate: 0.0010
# Epoch 46/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0507 - val_loss: 0.0243 - learning_rate: 0.0010
# Epoch 47/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0506 - val_loss: 0.0242 - learning_rate: 0.0010
# Epoch 48/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0504 - val_loss: 0.0240 - learning_rate: 0.0010
# Epoch 49/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0502 - val_loss: 0.0238 - learning_rate: 0.0010
# Epoch 50/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0500 - val_loss: 0.0237 - learning_rate: 0.0010
# Epoch 51/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0498 - val_loss: 0.0235 - learning_rate: 0.0010
# Epoch 52/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0496 - val_loss: 0.0233 - learning_rate: 0.0010
# Epoch 53/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0494 - val_loss: 0.0231 - learning_rate: 0.0010
# Epoch 54/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0492 - val_loss: 0.0229 - learning_rate: 0.0010
# Epoch 55/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0489 - val_loss: 0.0227 - learning_rate: 0.0010
# Epoch 56/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0487 - val_loss: 0.0224 - learning_rate: 0.0010
# Epoch 57/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0484 - val_loss: 0.0222 - learning_rate: 0.0010
# Epoch 58/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0482 - val_loss: 0.0220 - learning_rate: 0.0010
# Epoch 59/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0479 - val_loss: 0.0217 - learning_rate: 0.0010
# Epoch 60/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0477 - val_loss: 0.0215 - learning_rate: 0.0010
# Epoch 61/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0474 - val_loss: 0.0212 - learning_rate: 0.0010
# Epoch 62/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0472 - val_loss: 0.0209 - learning_rate: 0.0010
# Epoch 63/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0469 - val_loss: 0.0207 - learning_rate: 0.0010
# Epoch 64/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0466 - val_loss: 0.0204 - learning_rate: 0.0010
# Epoch 65/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0464 - val_loss: 0.0201 - learning_rate: 0.0010
# Epoch 66/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0462 - val_loss: 0.0199 - learning_rate: 0.0010
# Epoch 67/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0459 - val_loss: 0.0196 - learning_rate: 0.0010
# Epoch 68/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0457 - val_loss: 0.0194 - learning_rate: 0.0010
# Epoch 69/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0455 - val_loss: 0.0192 - learning_rate: 0.0010
# Epoch 70/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0453 - val_loss: 0.0189 - learning_rate: 0.0010
# Epoch 71/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0451 - val_loss: 0.0187 - learning_rate: 0.0010
# Epoch 72/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0450 - val_loss: 0.0185 - learning_rate: 0.0010
# Epoch 73/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0448 - val_loss: 0.0184 - learning_rate: 0.0010
# Epoch 74/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0447 - val_loss: 0.0182 - learning_rate: 0.0010
# Epoch 75/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0446 - val_loss: 0.0180 - learning_rate: 0.0010
# Epoch 76/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0445 - val_loss: 0.0179 - learning_rate: 0.0010
# Epoch 77/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0444 - val_loss: 0.0177 - learning_rate: 0.0010
# Epoch 78/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0443 - val_loss: 0.0176 - learning_rate: 0.0010
# Epoch 79/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0442 - val_loss: 0.0175 - learning_rate: 0.0010
# Epoch 80/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0441 - val_loss: 0.0174 - learning_rate: 0.0010
# Epoch 81/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0441 - val_loss: 0.0173 - learning_rate: 0.0010
# Epoch 82/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0440 - val_loss: 0.0172 - learning_rate: 0.0010
# Epoch 83/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0440 - val_loss: 0.0172 - learning_rate: 0.0010
# Epoch 84/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0439 - val_loss: 0.0171 - learning_rate: 0.0010
# Epoch 85/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0438 - val_loss: 0.0170 - learning_rate: 0.0010
# Epoch 86/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0437 - val_loss: 0.0168 - learning_rate: 0.0010
# Epoch 87/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0437 - val_loss: 0.0168 - learning_rate: 0.0010
# Epoch 88/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0437 - val_loss: 0.0167 - learning_rate: 0.0010
# Epoch 89/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0436 - val_loss: 0.0166 - learning_rate: 0.0010
# Epoch 90/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0436 - val_loss: 0.0166 - learning_rate: 0.0010
# Epoch 91/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0435 - val_loss: 0.0166 - learning_rate: 0.0010
# Epoch 92/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0435 - val_loss: 0.0165 - learning_rate: 0.0010
# Epoch 93/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0435 - val_loss: 0.0165 - learning_rate: 0.0010
# Epoch 94/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0435 - val_loss: 0.0165 - learning_rate: 0.0010
# Epoch 95/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0434 - val_loss: 0.0165 - learning_rate: 0.0010
# Epoch 96/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0434 - val_loss: 0.0164 - learning_rate: 0.0010
# Epoch 97/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0434 - val_loss: 0.0164 - learning_rate: 0.0010
# Epoch 98/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0434 - val_loss: 0.0164 - learning_rate: 0.0010
# Epoch 99/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0434 - val_loss: 0.0164 - learning_rate: 0.0010
# Epoch 100/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0433 - val_loss: 0.0164 - learning_rate: 0.0010
# Epoch 101/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0433 - val_loss: 0.0163 - learning_rate: 0.0010
# Epoch 102/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0433 - val_loss: 0.0163 - learning_rate: 0.0010
# Epoch 103/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0433 - val_loss: 0.0163 - learning_rate: 0.0010
# Epoch 104/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0433 - val_loss: 0.0163 - learning_rate: 0.0010
# Epoch 105/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0432 - val_loss: 0.0163 - learning_rate: 0.0010
# Epoch 106/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0432 - val_loss: 0.0162 - learning_rate: 0.0010
# Epoch 107/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0432 - val_loss: 0.0163 - learning_rate: 0.0010
# Epoch 108/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0432 - val_loss: 0.0164 - learning_rate: 0.0010
# Epoch 109/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0432 - val_loss: 0.0163 - learning_rate: 0.0010
# Epoch 110/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0432 - val_loss: 0.0162 - learning_rate: 0.0010
# Epoch 111/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0431 - val_loss: 0.0162 - learning_rate: 0.0010
# Epoch 112/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0431 - val_loss: 0.0161 - learning_rate: 0.0010
# Epoch 113/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0431 - val_loss: 0.0163 - learning_rate: 0.0010
# Epoch 114/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0431 - val_loss: 0.0163 - learning_rate: 0.0010
# Epoch 115/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0431 - val_loss: 0.0161 - learning_rate: 0.0010
# Epoch 116/200
#  1/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0187
# Epoch 116: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0431 - val_loss: 0.0162 - learning_rate: 0.0010
# Epoch 117/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0428 - val_loss: 0.0163 - learning_rate: 5.0000e-04
# Epoch 118/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0428 - val_loss: 0.0163 - learning_rate: 5.0000e-04
# Epoch 119/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0428 - val_loss: 0.0164 - learning_rate: 5.0000e-04
# Epoch 120/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0428 - val_loss: 0.0163 - learning_rate: 5.0000e-04
# Epoch 121/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0428 - val_loss: 0.0164 - learning_rate: 5.0000e-04
# Epoch 122/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0428 - val_loss: 0.0163 - learning_rate: 5.0000e-04
# Epoch 123/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0428 - val_loss: 0.0163 - learning_rate: 5.0000e-04
# Epoch 124/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0428 - val_loss: 0.0164 - learning_rate: 5.0000e-04
# Epoch 125/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0427 - val_loss: 0.0163 - learning_rate: 5.0000e-04
# Epoch 126/200
#  1/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0189
# Epoch 126: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0427 - val_loss: 0.0163 - learning_rate: 5.0000e-04
# Epoch 127/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0426 - val_loss: 0.0164 - learning_rate: 2.5000e-04
# Epoch 128/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0426 - val_loss: 0.0164 - learning_rate: 2.5000e-04
# Epoch 129/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0426 - val_loss: 0.0164 - learning_rate: 2.5000e-04
# Epoch 130/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0426 - val_loss: 0.0164 - learning_rate: 2.5000e-04
# Epoch 131/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0426 - val_loss: 0.0164 - learning_rate: 2.5000e-04
# Epoch 132/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0426 - val_loss: 0.0164 - learning_rate: 2.5000e-04
# Epoch 132: early stopping
# Restoring model weights from the end of the best epoch: 112.
# Training completed!

# %% [markdown]
# ## Evaluate with MSE, RMSE, and R2

# %%
y_pred_scaled = model.predict(X_test, verbose=0)

mse_scaled = mean_squared_error(y_test, y_pred_scaled)
rmse_scaled = np.sqrt(mse_scaled)
r2_scaled = r2_score(y_test, y_pred_scaled)

print('=== Metrics on Scaled Data ===')
print(f'MSE (scaled):  {mse_scaled:.6f}')
print(f'RMSE (scaled): {rmse_scaled:.6f}')
print(f'R² (scaled):   {r2_scaled:.6f}')

model.save('lstm_model_air_so2_forecast.keras')
# Out:
# === Metrics on Scaled Data ===
# MSE (scaled):  0.028307
# RMSE (scaled): 0.168247
# R² (scaled):   -0.048719

# %% [markdown]
# ## Inverse Scale Predictions

# %%
# ─── Inverse-scale ────────────────────────────────────────────────────────────
# y_test and y_pred are shape (samples,) — reshape to (samples, 1) for scaler
y_pred_diff = scaler.inverse_transform(y_pred_scaled.reshape(-1, 1))  # (samples, 1)
y_test_diff = scaler.inverse_transform(y_test.reshape(-1, 1))         # (samples, 1)

# ─── Undo differencing ────────────────────────────────────────────────────────
# Each predicted value at position i corresponds to log_series index:
# -(test_size) + i, so the anchor is always log_series aligned to the TEST window

if difference_order == 0:
    y_pred_log_values = y_pred_diff
    y_test_log_values = y_test_diff  # already in log domain after inverse-scale

elif difference_order == 1:
    # anchor: the actual log value ONE step before each test prediction
    # log_series[-test_size - 1 : -1] gives exactly test_size anchor points
    prev1 = log_series.iloc[-test_size - 1:-1].values.reshape(-1, 1)
    y_pred_log_values = y_pred_diff + prev1
    y_test_log_values = log_series.iloc[-test_size:].values.reshape(-1, 1)

else:  # difference_order == 2
    prev1 = log_series.iloc[-test_size - 1:-1].values.reshape(-1, 1)
    prev2 = log_series.iloc[-test_size - 2:-2].values.reshape(-1, 1)
    y_pred_log_values = y_pred_diff + 2 * prev1 - prev2
    y_test_log_values = log_series.iloc[-test_size:].values.reshape(-1, 1)

# ─── Undo log transform ───────────────────────────────────────────────────────
y_pred_original = np.exp(y_pred_log_values)
y_test_original = np.exp(y_test_log_values)

# ─── Sanity checks ────────────────────────────────────────────────────────────
assert y_pred_original.shape == y_test_original.shape, \
    f"Shape mismatch! Preds: {y_pred_original.shape}, Actuals: {y_test_original.shape}"
assert len(y_pred_original) == test_size, \
    f"Expected {test_size} predictions, got {len(y_pred_original)}"

# ─── Metrics on original scale ────────────────────────────────────────────────
mse_original  = mean_squared_error(y_test_original, y_pred_original)
rmse_original = np.sqrt(mse_original)
r2_original   = r2_score(y_test_original, y_pred_original)

print("=== Metrics on Original Scale ===")
print(f"MSE  (original): {mse_original:.20f}")
print(f"RMSE (original): {rmse_original:.20f}")
print(f"R²   (original): {r2_original:.6f}")
# Out:
# === Metrics on Original Scale ===
# MSE  (original): 0.00000000429649265865
# RMSE (original): 0.00006554763656040060
# R²   (original): -0.767700

# %%
# Create prediction vs actual plot
plt.figure(figsize=(14, 6))

# Plot flattened actual values and predictions
plt.plot(y_test_original.flatten(), marker='o', linestyle='-', 
         linewidth=1.5, label='Actual', color='#2E86AB', markersize=4)
plt.plot(y_pred_original.flatten(), marker='s', linestyle='--', 
         linewidth=1.5, label='LSTM Prediction', color='#A23B72', markersize=4)

plt.title('LSTM Forecast vs Actual', fontsize=14, fontweight='bold')
plt.xlabel('Flattened Test Points', fontsize=12)
plt.ylabel('SO2 Concentration (%)', fontsize=12)
plt.legend(fontsize=11, loc='best')
plt.grid(True, alpha=0.3)

# Add metrics to the plot
metrics_text = f'MSE: {mse_original:.20f}\nRMSE: {rmse_original:.20f}\nR²: {r2_original:.4f}'
plt.text(0.02, 0.98, metrics_text, transform=plt.gca().transAxes, 
         fontsize=11, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))

plt.tight_layout()
plt.show()

print(f"\n✓ Forecast completed successfully!")
# Out:
# ✓ Forecast completed successfully!
