# %% [markdown]
# # LSTM Forecast for air_so2
# This notebook builds an LSTM model to forecast the univariate air_so2 series using a 12-step lookback window with MinMax scaling applied after the train-test split.

# %% [markdown]
# ## Import Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import zscore
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score
from statsmodels.tsa.stattools import adfuller
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Load the CSV Dataset

# %%
# Load the dataset
df = pd.read_csv('../public/data/combined_air_electricity_ipi_cleaned.csv')

df['date'] = pd.to_datetime(df['date'])
df = df.sort_values('date').reset_index(drop=True)

target_col = 'air_so2'
print(f'Forecast target: {target_col}')
print(f"Dataset shape before outlier removal: {df.shape}")
print(f"First 5 rows:")
print(df[['date', target_col]].head())
print(f"Last 5 rows:")
print(df[['date', target_col]].tail())

z_scores = np.abs(zscore(df[target_col]))

df[target_col] = np.where(
    z_scores > 3,
    np.nan,
    df[target_col]
)

df[target_col] = df[target_col].interpolate()
print(f"First 5 rows after outlier smoothing:")
print(df[['date', target_col]].head())
print(f"Last 5 rows after outlier smoothing:")
print(df[['date', target_col]].tail())
# Out:
# Forecast target: air_so2
# Dataset shape before outlier removal: (60, 19)
# First 5 rows:
#         date  air_so2
# 0 2018-01-01   0.0010
# 1 2018-02-01   0.0011
# 2 2018-03-01   0.0010
# 3 2018-04-01   0.0010
# 4 2018-05-01   0.0010
# Last 5 rows:
#          date  air_so2
# 55 2022-08-01   0.0012
# 56 2022-09-01   0.0012
# 57 2022-10-01   0.0012
# 58 2022-11-01   0.0012
# 59 2022-12-01   0.0013
# First 5 rows after outlier smoothing:
#         date  air_so2
# 0 2018-01-01   0.0010
# 1 2018-02-01   0.0011
# 2 2018-03-01   0.0010
# 3 2018-04-01   0.0010
# 4 2018-05-01   0.0010
# Last 5 rows after outlier smoothing:
#          date  air_so2
# 55 2022-08-01   0.0012
# 56 2022-09-01   0.0012
# 57 2022-10-01   0.0012
# 58 2022-11-01   0.0012
# 59 2022-12-01   0.0013

# %% [markdown]
# ## Parse Dates and Sort Data

# %%
print(f"Date range: {df['date'].min()} to {df['date'].max()}")
print(f"Total months after outlier removal: {len(df)}")
# Out:
# Date range: 2018-01-01 00:00:00 to 2022-12-01 00:00:00
# Total months after outlier removal: 60

# %% [markdown]
# ## Create Time Series Index and Target

# %%
df.set_index('date', inplace=True)
df[f'log_{target_col}'] = np.log(df[target_col])
log_series = df[f'log_{target_col}']
print(f'Log transformation applied to {target_col}.')

def run_adf_test(series, alpha=0.05):
    result = adfuller(series, autolag='AIC')
    print(f'ADF statistic: {result[0]:.4f}, p-value: {result[1]:.4f}, usedlag: {result[2]}, nobs: {result[3]}')
    return result[1] <= alpha

difference_order = 0
processed_series = log_series.copy()
print('ADF test on log-transformed series:')
if not run_adf_test(processed_series):
    processed_series = processed_series.diff().dropna()
    difference_order = 1
    print('Series was not stationary. Applied first-order differencing.')
    print('ADF test after first differencing:')
    if not run_adf_test(processed_series):
        processed_series = processed_series.diff().dropna()
        difference_order = 2
        print('Series still not stationary. Applied second-order differencing.')
        print('ADF test after second differencing:')
        if not run_adf_test(processed_series):
            print('Warning: series is still non-stationary after second differencing.')

if difference_order == 0:
    print('Final series uses log-transformed values with no differencing.')
else:
    print(f'Final series uses log-transformed values with differencing order = {difference_order}.')

print(f'Final processed data length: {len(processed_series)}')
data = processed_series.values.reshape(-1, 1)
print(f'Data shape: {data.shape}')
# Out:
# Log transformation applied to air_so2.
# ADF test on log-transformed series:
# ADF statistic: 0.4149, p-value: 0.9820, usedlag: 11, nobs: 48
# Series was not stationary. Applied first-order differencing.
# ADF test after first differencing:
# ADF statistic: -5.7568, p-value: 0.0000, usedlag: 10, nobs: 48
# Final series uses log-transformed values with differencing order = 1.
# Final processed data length: 59
# Data shape: (59, 1)

# %% [markdown]
# ## Split Data into Train and Test (Last 12 Months)

# %%
test_size = 12
train_data = data[:-test_size]
test_data = data[-test_size:]

print(f'Train data shape: {train_data.shape}')
print(f'Test data shape: {test_data.shape}')
print(f'Train range: {len(train_data)} months')
print(f'Test range: {len(test_data)} months')
# Out:
# Train data shape: (47, 1)
# Test data shape: (12, 1)
# Train range: 47 months
# Test range: 12 months

# %% [markdown]
# ## Scale Data with MinMaxScaler After Split

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
train_scaled = scaler.fit_transform(train_data)
test_scaled = scaler.transform(test_data)

print(f'Scaled train shape: {train_scaled.shape}')
print(f'Scaled test shape: {test_scaled.shape}')
print(f'Scaler min: {scaler.data_min_[0]:.2f}, max: {scaler.data_max_[0]:.2f}')
# Out:
# Scaled train shape: (47, 1)
# Scaled test shape: (12, 1)
# Scaler min: -0.17, max: 0.17

# %% [markdown]
# ## Create LSTM Input Sequences

# %%
def create_sequences(data, lookback=3):
    X, y = [], []
    for i in range(lookback, len(data)):
        X.append(data[i - lookback:i, 0:1])
        y.append(data[i, 0])
    return np.array(X), np.array(y)

lookback = 3

X_train, y_train = create_sequences(train_scaled, lookback)

test_extended = np.vstack((train_scaled[-lookback:], test_scaled))
X_test, y_test = create_sequences(test_extended, lookback)

print(f'X_train shape: {X_train.shape}')
print(f'X_test shape: {X_test.shape}')
print(f'Selected lookback from ACF: {lookback}')
# Out:
# X_train shape: (44, 3, 1)
# X_test shape: (12, 3, 1)
# Selected lookback from ACF: 3

# %% [markdown]
# ## Train the Model

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2

print('Training the LSTM model with walk-forward validation...')

def create_model(lookback=3):
    model = Sequential([
        LSTM(8, input_shape=(lookback, 1),
             kernel_regularizer=l2(1e-4),
             recurrent_regularizer=l2(1e-4)),
        Dense(4, activation='relu', kernel_regularizer=l2(1e-4)),
        Dense(1)
    ])
    model.compile(optimizer='adam', loss='mse')
    return model

def walk_forward_validation(scaled_data, lookback=3, val_size=4, n_splits=3):
    total_len = len(scaled_data)
    max_splits = (total_len - lookback - val_size) // val_size
    if max_splits < 1:
        raise ValueError('Not enough data for walk-forward validation with the given parameters.')

    n_splits = min(n_splits, max_splits)
    metrics = []

    for split in range(n_splits):
        initial_train_size = 20           # reduced: 30 was too large for 48 pts
        train_end = initial_train_size + (split + 1) * val_size
        val_start = train_end
        val_end = val_start + val_size

        if val_end > total_len:
            print(f'Fold {split + 1}: not enough data, skipping.')
            break

        train_window = scaled_data[:train_end]
        val_window = scaled_data[val_start:val_end]

        X_train_w, y_train_w = create_sequences(train_window, lookback)
        X_val_w, y_val_w = create_sequences(
            np.vstack((train_window[-lookback:], val_window)),
            lookback
        )

        fold_model = create_model(lookback)
        fold_model.fit(
            X_train_w,
            y_train_w,
            epochs=200,                   # more epochs, early stopping will brake
            batch_size=2,                 # tiny batch for small data
            validation_data=(X_val_w, y_val_w),
            callbacks=[
                EarlyStopping(
                    monitor='val_loss',
                    patience=20,          # more patience to avoid premature stop
                    restore_best_weights=True,
                    verbose=0
                ),
                ReduceLROnPlateau(        # decay LR when val_loss plateaus
                    monitor='val_loss',
                    factor=0.5,
                    patience=10,
                    min_lr=1e-5,
                    verbose=0
                )
            ],
            shuffle=False,
            verbose=0
        )

        y_val_pred = fold_model.predict(X_val_w, verbose=0)
        mse = mean_squared_error(y_val_w, y_val_pred)
        rmse = np.sqrt(mse)
        r2 = r2_score(y_val_w, y_val_pred)
        metrics.append((mse, rmse, r2))

        print(
            f'Fold {split + 1}: train_end={train_end}, val_end={val_end}, '
            f'MSE={mse:.6f}, RMSE={rmse:.6f}, R²={r2:.6f}'
        )

    return metrics

# val_size=4, n_splits=3 — keeps each fold's val set small and folds feasible
metrics = walk_forward_validation(train_scaled, lookback=lookback, val_size=4, n_splits=3)

mse_values = [m[0] for m in metrics]
rmse_values = [m[1] for m in metrics]
r2_values = [m[2] for m in metrics]

print('Walk-forward validation summary:')
print(f'Average MSE:  {np.mean(mse_values):.6f}')
print(f'Average RMSE: {np.mean(rmse_values):.6f}')
print(f'Average R²:   {np.mean(r2_values):.6f}')

print('Training final model on the full training set...')
model = create_model(lookback)
history = model.fit(
    X_train,
    y_train,
    epochs=200,
    batch_size=2,                         # small batch for final train too
    validation_split=0.15,
    callbacks=[
        EarlyStopping(
            monitor='val_loss',
            patience=20,
            restore_best_weights=True,
            verbose=1
        ),
        ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.5,
            patience=10,
            min_lr=1e-5,
            verbose=1
        )
    ],
    shuffle=False,
    verbose=1
)

print('Training completed!')
# Out:
# Training the LSTM model with walk-forward validation...
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Fold 1: train_end=24, val_end=28, MSE=0.025830, RMSE=0.160718, R²=-0.385310
# Fold 2: train_end=28, val_end=32, MSE=0.050509, RMSE=0.224741, R²=-1.229043
# Fold 3: train_end=32, val_end=36, MSE=0.031915, RMSE=0.178647, R²=0.058883
# Walk-forward validation summary:
# Average MSE:  0.036085
# Average RMSE: 0.188035
# Average R²:   -0.518490
# Training final model on the full training set...
# Epoch 1/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.4577 - val_loss: 0.4459 - learning_rate: 0.0010
# Epoch 2/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3345 - val_loss: 0.3349 - learning_rate: 0.0010
# Epoch 3/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2661 - val_loss: 0.2948 - learning_rate: 0.0010
# Epoch 4/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2466 - val_loss: 0.2791 - learning_rate: 0.0010
# Epoch 5/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2334 - val_loss: 0.2639 - learning_rate: 0.0010
# Epoch 6/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2208 - val_loss: 0.2492 - learning_rate: 0.0010
# Epoch 7/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2087 - val_loss: 0.2352 - learning_rate: 0.0010
# Epoch 8/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1973 - val_loss: 0.2218 - learning_rate: 0.0010
# Epoch 9/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1864 - val_loss: 0.2091 - learning_rate: 0.0010
# Epoch 10/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1761 - val_loss: 0.1970 - learning_rate: 0.0010
# Epoch 11/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1665 - val_loss: 0.1855 - learning_rate: 0.0010
# Epoch 12/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1574 - val_loss: 0.1747 - learning_rate: 0.0010
# Epoch 13/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1488 - val_loss: 0.1645 - learning_rate: 0.0010
# Epoch 14/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1409 - val_loss: 0.1548 - learning_rate: 0.0010
# Epoch 15/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1334 - val_loss: 0.1457 - learning_rate: 0.0010
# Epoch 16/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1265 - val_loss: 0.1372 - learning_rate: 0.0010
# Epoch 17/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1200 - val_loss: 0.1292 - learning_rate: 0.0010
# Epoch 18/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1140 - val_loss: 0.1216 - learning_rate: 0.0010
# Epoch 19/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1084 - val_loss: 0.1146 - learning_rate: 0.0010
# Epoch 20/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1033 - val_loss: 0.1080 - learning_rate: 0.0010
# Epoch 21/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0985 - val_loss: 0.1018 - learning_rate: 0.0010
# Epoch 22/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0941 - val_loss: 0.0961 - learning_rate: 0.0010
# Epoch 23/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0900 - val_loss: 0.0907 - learning_rate: 0.0010
# Epoch 24/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0862 - val_loss: 0.0857 - learning_rate: 0.0010
# Epoch 25/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0828 - val_loss: 0.0810 - learning_rate: 0.0010
# Epoch 26/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0796 - val_loss: 0.0767 - learning_rate: 0.0010
# Epoch 27/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0768 - val_loss: 0.0726 - learning_rate: 0.0010
# Epoch 28/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0741 - val_loss: 0.0689 - learning_rate: 0.0010
# Epoch 29/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0717 - val_loss: 0.0654 - learning_rate: 0.0010
# Epoch 30/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0695 - val_loss: 0.0621 - learning_rate: 0.0010
# Epoch 31/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0674 - val_loss: 0.0591 - learning_rate: 0.0010
# Epoch 32/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0656 - val_loss: 0.0564 - learning_rate: 0.0010
# Epoch 33/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0639 - val_loss: 0.0538 - learning_rate: 0.0010
# Epoch 34/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0624 - val_loss: 0.0514 - learning_rate: 0.0010
# Epoch 35/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0610 - val_loss: 0.0492 - learning_rate: 0.0010
# Epoch 36/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0598 - val_loss: 0.0471 - learning_rate: 0.0010
# Epoch 37/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0587 - val_loss: 0.0453 - learning_rate: 0.0010
# Epoch 38/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0576 - val_loss: 0.0435 - learning_rate: 0.0010
# Epoch 39/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0567 - val_loss: 0.0419 - learning_rate: 0.0010
# Epoch 40/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0559 - val_loss: 0.0404 - learning_rate: 0.0010
# Epoch 41/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0551 - val_loss: 0.0390 - learning_rate: 0.0010
# Epoch 42/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0545 - val_loss: 0.0377 - learning_rate: 0.0010
# Epoch 43/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0539 - val_loss: 0.0366 - learning_rate: 0.0010
# Epoch 44/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0533 - val_loss: 0.0355 - learning_rate: 0.0010
# Epoch 45/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0528 - val_loss: 0.0345 - learning_rate: 0.0010
# Epoch 46/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0524 - val_loss: 0.0336 - learning_rate: 0.0010
# Epoch 47/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0520 - val_loss: 0.0327 - learning_rate: 0.0010
# Epoch 48/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0516 - val_loss: 0.0320 - learning_rate: 0.0010
# Epoch 49/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0513 - val_loss: 0.0313 - learning_rate: 0.0010
# Epoch 50/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0510 - val_loss: 0.0306 - learning_rate: 0.0010
# Epoch 51/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0507 - val_loss: 0.0300 - learning_rate: 0.0010
# Epoch 52/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0505 - val_loss: 0.0294 - learning_rate: 0.0010
# Epoch 53/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0502 - val_loss: 0.0288 - learning_rate: 0.0010
# Epoch 54/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0501 - val_loss: 0.0283 - learning_rate: 0.0010
# Epoch 55/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0499 - val_loss: 0.0279 - learning_rate: 0.0010
# Epoch 56/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0497 - val_loss: 0.0274 - learning_rate: 0.0010
# Epoch 57/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0496 - val_loss: 0.0271 - learning_rate: 0.0010
# Epoch 58/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0494 - val_loss: 0.0267 - learning_rate: 0.0010
# Epoch 59/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0493 - val_loss: 0.0263 - learning_rate: 0.0010
# Epoch 60/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0492 - val_loss: 0.0260 - learning_rate: 0.0010
# Epoch 61/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0491 - val_loss: 0.0257 - learning_rate: 0.0010
# Epoch 62/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0489 - val_loss: 0.0255 - learning_rate: 0.0010
# Epoch 63/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0489 - val_loss: 0.0252 - learning_rate: 0.0010
# Epoch 64/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0487 - val_loss: 0.0249 - learning_rate: 0.0010
# Epoch 65/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0486 - val_loss: 0.0246 - learning_rate: 0.0010
# Epoch 66/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0485 - val_loss: 0.0243 - learning_rate: 0.0010
# Epoch 67/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0485 - val_loss: 0.0241 - learning_rate: 0.0010
# Epoch 68/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0484 - val_loss: 0.0239 - learning_rate: 0.0010
# Epoch 69/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0483 - val_loss: 0.0237 - learning_rate: 0.0010
# Epoch 70/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0482 - val_loss: 0.0235 - learning_rate: 0.0010
# Epoch 71/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0482 - val_loss: 0.0234 - learning_rate: 0.0010
# Epoch 72/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0481 - val_loss: 0.0232 - learning_rate: 0.0010
# Epoch 73/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0480 - val_loss: 0.0231 - learning_rate: 0.0010
# Epoch 74/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0480 - val_loss: 0.0229 - learning_rate: 0.0010
# Epoch 75/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0479 - val_loss: 0.0228 - learning_rate: 0.0010
# Epoch 76/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0479 - val_loss: 0.0226 - learning_rate: 0.0010
# Epoch 77/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0478 - val_loss: 0.0225 - learning_rate: 0.0010
# Epoch 78/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0478 - val_loss: 0.0224 - learning_rate: 0.0010
# Epoch 79/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0477 - val_loss: 0.0224 - learning_rate: 0.0010
# Epoch 80/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0476 - val_loss: 0.0229 - learning_rate: 0.0010
# Epoch 81/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0474 - val_loss: 0.0231 - learning_rate: 0.0010
# Epoch 82/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0473 - val_loss: 0.0237 - learning_rate: 0.0010
# Epoch 83/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0473 - val_loss: 0.0240 - learning_rate: 0.0010
# Epoch 84/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0472 - val_loss: 0.0240 - learning_rate: 0.0010
# Epoch 85/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0471 - val_loss: 0.0233 - learning_rate: 0.0010
# Epoch 86/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0469 - val_loss: 0.0233 - learning_rate: 0.0010
# Epoch 87/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0468 - val_loss: 0.0234 - learning_rate: 0.0010
# Epoch 88/200
#  1/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0386
# Epoch 88: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0468 - val_loss: 0.0230 - learning_rate: 0.0010
# Epoch 89/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0465 - val_loss: 0.0229 - learning_rate: 5.0000e-04
# Epoch 90/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0465 - val_loss: 0.0230 - learning_rate: 5.0000e-04
# Epoch 91/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0464 - val_loss: 0.0228 - learning_rate: 5.0000e-04
# Epoch 92/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0464 - val_loss: 0.0228 - learning_rate: 5.0000e-04
# Epoch 93/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0463 - val_loss: 0.0226 - learning_rate: 5.0000e-04
# Epoch 94/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0463 - val_loss: 0.0226 - learning_rate: 5.0000e-04
# Epoch 95/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0463 - val_loss: 0.0225 - learning_rate: 5.0000e-04
# Epoch 96/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0462 - val_loss: 0.0225 - learning_rate: 5.0000e-04
# Epoch 97/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0462 - val_loss: 0.0227 - learning_rate: 5.0000e-04
# Epoch 98/200
#  1/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0369
# Epoch 98: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0462 - val_loss: 0.0225 - learning_rate: 5.0000e-04
# Epoch 99/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0460 - val_loss: 0.0224 - learning_rate: 2.5000e-04
# Epoch 99: early stopping
# Restoring model weights from the end of the best epoch: 79.
# Training completed!

# %% [markdown]
# ## Evaluate with MSE, RMSE, and R2

# %%
y_pred_scaled = model.predict(X_test, verbose=0)

mse_scaled = mean_squared_error(y_test, y_pred_scaled)
rmse_scaled = np.sqrt(mse_scaled)
r2_scaled = r2_score(y_test, y_pred_scaled)

print('=== Metrics on Scaled Data ===')
print(f'MSE (scaled):  {mse_scaled:.6f}')
print(f'RMSE (scaled): {rmse_scaled:.6f}')
print(f'R² (scaled):   {r2_scaled:.6f}')

# 1. Save the model architecture to a JSON file
model_json = model.to_json()
with open("lstm_model_air_so2_forecast.json", "w") as json_file:
    json_file.write(model_json)

# 2. Save the weights to a separate HDF5 file
model.save_weights("lstm_model_air_so2_forecast.weights.h5")
# Out:
# === Metrics on Scaled Data ===
# MSE (scaled):  0.026479
# RMSE (scaled): 0.162723
# R² (scaled):   0.019009

# %% [markdown]
# ## Inverse Scale Predictions

# %%
# ─── Inverse-scale ────────────────────────────────────────────────────────────
# y_test and y_pred are shape (samples,) — reshape to (samples, 1) for scaler
y_pred_diff = scaler.inverse_transform(y_pred_scaled.reshape(-1, 1))  # (samples, 1)
y_test_diff = scaler.inverse_transform(y_test.reshape(-1, 1))         # (samples, 1)

# ─── Undo differencing ────────────────────────────────────────────────────────
# Each predicted value at position i corresponds to log_series index:
# -(test_size) + i, so the anchor is always log_series aligned to the TEST window

if difference_order == 0:
    y_pred_log_values = y_pred_diff
    y_test_log_values = y_test_diff  # already in log domain after inverse-scale

elif difference_order == 1:
    # anchor: the actual log value ONE step before each test prediction
    # log_series[-test_size - 1 : -1] gives exactly test_size anchor points
    prev1 = log_series.iloc[-test_size - 1:-1].values.reshape(-1, 1)
    y_pred_log_values = y_pred_diff + prev1
    y_test_log_values = log_series.iloc[-test_size:].values.reshape(-1, 1)

else:  # difference_order == 2
    prev1 = log_series.iloc[-test_size - 1:-1].values.reshape(-1, 1)
    prev2 = log_series.iloc[-test_size - 2:-2].values.reshape(-1, 1)
    y_pred_log_values = y_pred_diff + 2 * prev1 - prev2
    y_test_log_values = log_series.iloc[-test_size:].values.reshape(-1, 1)

# ─── Undo log transform ───────────────────────────────────────────────────────
y_pred_original = np.exp(y_pred_log_values)
y_test_original = np.exp(y_test_log_values)

# ─── Sanity checks ────────────────────────────────────────────────────────────
assert y_pred_original.shape == y_test_original.shape, \
    f"Shape mismatch! Preds: {y_pred_original.shape}, Actuals: {y_test_original.shape}"
assert len(y_pred_original) == test_size, \
    f"Expected {test_size} predictions, got {len(y_pred_original)}"

# ─── Metrics on original scale ────────────────────────────────────────────────
mse_original  = mean_squared_error(y_test_original, y_pred_original)
rmse_original = np.sqrt(mse_original)
r2_original   = r2_score(y_test_original, y_pred_original)

print("=== Metrics on Original Scale ===")
print(f"MSE  (original): {mse_original:.20f}")
print(f"RMSE (original): {rmse_original:.20f}")
print(f"R²   (original): {r2_original:.6f}")
# Out:
# === Metrics on Original Scale ===
# MSE  (original): 0.00000000402694181476
# RMSE (original): 0.00006345818950113366
# R²   (original): -0.656799

# %%
# Create prediction vs actual plot
plt.figure(figsize=(14, 6))

# Plot flattened actual values and predictions
plt.plot(y_test_original.flatten(), marker='o', linestyle='-', 
         linewidth=1.5, label='Actual', color='#2E86AB', markersize=4)
plt.plot(y_pred_original.flatten(), marker='s', linestyle='--', 
         linewidth=1.5, label='LSTM Prediction', color='#A23B72', markersize=4)

plt.title('LSTM Forecast vs Actual', fontsize=14, fontweight='bold')
plt.xlabel('Flattened Test Points', fontsize=12)
plt.ylabel('SO2 Concentration (%)', fontsize=12)
plt.legend(fontsize=11, loc='best')
plt.grid(True, alpha=0.3)

# Add metrics to the plot
metrics_text = f'MSE: {mse_original:.20f}\nRMSE: {rmse_original:.20f}\nR²: {r2_original:.4f}'
plt.text(0.02, 0.98, metrics_text, transform=plt.gca().transAxes, 
         fontsize=11, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))

plt.tight_layout()
plt.show()

print(f"\n✓ Forecast completed successfully!")
# Out:
# ✓ Forecast completed successfully!
